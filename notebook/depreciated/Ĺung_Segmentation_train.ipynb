# %%
import os

import numpy as np
import cv2
import matplotlib.pyplot as plt

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler

from glob import glob
from tqdm import tqdm

# %%
INPUT_DIR = os.path.join("/mnt/data/Smart-Detect/Segmentation/", "input_segmentation")

SEGMENTATION_MODEL = os.path.join(INPUT_DIR, "unet_lung_seg.hdf5")

SEGMENTATION_DIR = os.path.join(INPUT_DIR, "segmentation")

SEGMENTATION_TEST_DIR = os.path.join(SEGMENTATION_DIR, "test")
SEGMENTATION_TRAIN_DIR = os.path.join(SEGMENTATION_DIR, "train")

SEGMENTATION_AUG_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "augmentation")
SEGMENTATION_IMAGE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "image")
SEGMENTATION_MASK_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "mask")
SEGMENTATION_DILATE_DIR = os.path.join(SEGMENTATION_TRAIN_DIR, "dilate")

SEGMENTATION_SOURCE_DIR = os.path.join(INPUT_DIR, "pulmonary-chest-xray-abnormalities")

SHENZHEN_TRAIN_DIR = os.path.join(SEGMENTATION_SOURCE_DIR,"ChinaSet_AllFiles")
SHENZHEN_IMAGE_DIR = os.path.join(SHENZHEN_TRAIN_DIR, "CXR_png_preproc")
SHENZHEN_MASK_DIR = os.path.join(SHENZHEN_TRAIN_DIR, "mask", "mask")

MONTGOMERY_TRAIN_DIR = os.path.join(SEGMENTATION_SOURCE_DIR, "Montgomery", "MontgomerySet")
MONTGOMERY_IMAGE_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, "CXR_png_preproc")
MONTGOMERY_LEFT_MASK_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, "ManualMask", "leftMask")
print(MONTGOMERY_LEFT_MASK_DIR)
MONTGOMERY_RIGHT_MASK_DIR = os.path.join(MONTGOMERY_TRAIN_DIR, "ManualMask", "rightMask")

MANUAL_TRAIN_DIR = os.path.join(SEGMENTATION_SOURCE_DIR,"Manual_seg")
MANUAL_IMAGE_DIR = os.path.join(MANUAL_TRAIN_DIR, "CXR_png_preproc")
MANUAL_MASK_DIR = os.path.join(MANUAL_TRAIN_DIR, "masks")

DILATE_KERNEL = np.ones((15, 15), np.uint8)

BATCH_SIZE=2

#Prod
EPOCHS=56

#Desv
#EPOCHS=16
# Out:
# /mnt/data/Smart-Detect/Segmentation/input_segmentation/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/ManualMask/leftMask

# %%
segmentation_model = load_model(SEGMENTATION_MODEL, \
                                custom_objects={'dice_coef_loss': dice_coef_loss, \
                                                'dice_coef': dice_coef})

segmentation_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3d2473e989fa> in <module>
# ----> 1 segmentation_model = load_model(SEGMENTATION_MODEL, \
#       2                                 custom_objects={'dice_coef_loss': dice_coef_loss, \
#       3                                                 'dice_coef': dice_coef})
#       4
#       5 segmentation_model.summary()
#
# NameError: name 'SEGMENTATION_MODEL' is not defined

# %%
montgomery_left_mask_dir = glob(os.path.join(MONTGOMERY_LEFT_MASK_DIR, '*.png'))
print(os.path.join(MONTGOMERY_LEFT_MASK_DIR, '*.png'))
montgomery_test = montgomery_left_mask_dir[0:20]
montgomery_train= montgomery_left_mask_dir[20:]

for left_image_file in tqdm(montgomery_left_mask_dir):
    base_file = os.path.basename(left_image_file)
    image_file = os.path.join(MONTGOMERY_IMAGE_DIR, base_file)
    right_image_file = os.path.join(MONTGOMERY_RIGHT_MASK_DIR, base_file)

    image = cv2.imread(image_file)
    left_mask = cv2.imread(left_image_file, cv2.IMREAD_GRAYSCALE)
    right_mask = cv2.imread(right_image_file, cv2.IMREAD_GRAYSCALE)
    
    image = cv2.resize(image, (512, 512))
    left_mask = cv2.resize(left_mask, (512, 512))
    right_mask = cv2.resize(right_mask, (512, 512))
    
    mask = np.maximum(left_mask, right_mask)
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (left_image_file in montgomery_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
#   0%|          | 0/138 [00:00<?, ?it/s]
# /mnt/data/Smart-Detect/Segmentation/input_segmentation/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/ManualMask/leftMask/*.png
# 100%|██████████| 138/138 [00:50<00:00,  2.73it/s]

# %%
def add_colored_dilate(image, mask_image, dilate_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    dilate_image_gray = cv2.cvtColor(dilate_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    dilate = cv2.bitwise_and(dilate_image, dilate_image, mask=dilate_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])
    dilate_coord = np.where(dilate!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]
    dilate[dilate_coord[0],dilate_coord[1],:] = [0,0,255]

    ret = cv2.addWeighted(image, 0.7, dilate, 0.3, 0)
    ret = cv2.addWeighted(ret, 0.7, mask, 0.3, 0)

    return ret

def add_colored_mask(image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(image, 0.7, mask, 0.3, 0)

    return ret

def diff_mask(ref_image, mask_image):
    mask_image_gray = cv2.cvtColor(mask_image, cv2.COLOR_BGR2GRAY)
    
    mask = cv2.bitwise_and(mask_image, mask_image, mask=mask_image_gray)
    
    mask_coord = np.where(mask!=[0,0,0])

    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]

    ret = cv2.addWeighted(ref_image, 0.7, mask, 0.3, 0)
    return ret

# %%
base_file = os.path.basename(montgomery_train[0])

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(montgomery_test[0])
filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext))

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
shenzhen_mask_dir = glob(os.path.join(SHENZHEN_MASK_DIR, '*.png'))
shenzhen_test = shenzhen_mask_dir[0:20]
shenzhen_train= shenzhen_mask_dir[20:]

for mask_file in tqdm(shenzhen_mask_dir):
    base_file = os.path.basename(mask_file).replace("_mask", "")
    image_file = os.path.join(SHENZHEN_IMAGE_DIR, base_file)

    image = cv2.imread(image_file)
    mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
        
    image = cv2.resize(image, (512, 512))
    mask = cv2.resize(mask, (512, 512))
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (mask_file in shenzhen_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)

        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 566/566 [01:58<00:00,  4.78it/s]

# %%
base_file = os.path.basename(shenzhen_train[0].replace("_mask", ""))

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(shenzhen_test[0].replace("_mask", ""))
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
filename, fileext = os.path.splitext(base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))

filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext))

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
manual_mask_dir = glob(os.path.join(MANUAL_MASK_DIR, '*.png'))
manual_test = manual_mask_dir[0:10]
manual_train= manual_mask_dir[10:]

for mask_file in tqdm(manual_mask_dir):
    base_file = os.path.basename(mask_file)
    image_file = os.path.join(MANUAL_IMAGE_DIR, base_file)

    image = cv2.imread(image_file)
    #image = (image*(-1))+255
    #npy = image /255
    mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
        
    image = cv2.resize(image, (512, 512))
    mask = cv2.resize(mask, (512, 512))
    mask_dilate = cv2.dilate(mask, DILATE_KERNEL, iterations=1)
    
    if (mask_file in manual_train):
        cv2.imwrite(os.path.join(SEGMENTATION_IMAGE_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_MASK_DIR, base_file), \
                    mask)
        cv2.imwrite(os.path.join(SEGMENTATION_DILATE_DIR, base_file), \
                    mask_dilate)
    else:
        filename, fileext = os.path.splitext(base_file)

        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, base_file), \
                    image)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_mask%s" % (filename, fileext)), mask)
        cv2.imwrite(os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext)), mask_dilate)
# Out:
# 100%|██████████| 188/188 [00:05<00:00, 31.66it/s]

# %%
base_file = os.path.basename(manual_train[0])

image_file = os.path.join(SEGMENTATION_IMAGE_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_MASK_DIR, base_file)
dilate_image_file = os.path.join(SEGMENTATION_DILATE_DIR, base_file)

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)
                          
fig, axs = plt.subplots(2, 4, figsize=(15, 8))

axs[0, 0].set_title("X-Ray")
axs[0, 0].imshow(image)

axs[0, 1].set_title("Mask")
axs[0, 1].imshow(mask_image)

axs[0, 2].set_title("Dilate")
axs[0, 2].imshow(dilate_image)

axs[0, 3].set_title("Merged")
axs[0, 3].imshow(merged_image)

base_file = os.path.basename(manual_test[0])
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
filename, fileext = os.path.splitext(base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))

filename, fileext = os.path.splitext(base_file)
image_file = os.path.join(SEGMENTATION_TEST_DIR, base_file)
mask_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                               "%s_mask%s" % (filename, fileext))
dilate_image_file = os.path.join(SEGMENTATION_TEST_DIR, \
                                 "%s_dilate%s" % (filename, fileext))

image = cv2.imread(image_file)
mask_image = cv2.imread(mask_image_file)
dilate_image = cv2.imread(dilate_image_file)
merged_image = add_colored_dilate(image, mask_image, dilate_image)

axs[1, 0].set_title("X-Ray")
axs[1, 0].imshow(image)

axs[1, 1].set_title("Mask")
axs[1, 1].imshow(mask_image)

axs[1, 2].set_title("Dilate")
axs[1, 2].imshow(dilate_image)

axs[1, 3].set_title("Merged")
axs[1, 3].imshow(merged_image)

# %%
train_files = glob(os.path.join(SEGMENTATION_IMAGE_DIR, "*.png"))
test_files = glob(os.path.join(SEGMENTATION_TEST_DIR, "*.png"))
mask_files = glob(os.path.join(SEGMENTATION_MASK_DIR, "*.png"))
dilate_files = glob(os.path.join(SEGMENTATION_DILATE_DIR, "*.png"))

(len(train_files), \
 len(test_files), \
 len(mask_files), \
 len(dilate_files))
# Out:
# (842, 200, 842, 842)

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(batch_size, train_path, image_folder, mask_folder, aug_dict,
        image_color_mode="grayscale",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
# From: https://github.com/jocicmarko/ultrasound-nerve-segmentation/blob/master/train.py
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def test_load_image(test_file, target_size=(256,256)):
    img = cv2.imread(test_file, cv2.IMREAD_GRAYSCALE)
    img = img / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

def test_generator(test_files, target_size=(256,256)):
    for test_file in test_files:
        yield test_load_image(test_file, target_size)
        
def save_result(save_path, npyfile, test_files):
    for i, item in enumerate(npyfile):
        result_file = test_files[i]
        img = (item[:, :, 0] * 255.).astype(np.uint8)

        filename, fileext = os.path.splitext(os.path.basename(result_file))

        result_file = os.path.join(save_path, "%s_predict%s" % (filename, fileext))

        cv2.imwrite(result_file, img)

# %%
def add_suffix(base_file, suffix):
    filename, fileext = os.path.splitext(base_file)
    return "%s_%s%s" % (filename, suffix, fileext)

test_files = [test_file for test_file in glob(os.path.join(SEGMENTATION_TEST_DIR, "*.png")) \
              if ("_mask" not in test_file \
                  and "_dilate" not in test_file \
                  and "_predict" not in test_file)]

validation_data = (test_load_image(test_files[0], target_size=(512, 512)),
                    test_load_image(add_suffix(test_files[0], "dilate"), target_size=(512, 512)))

len(test_files), len(validation_data)
# Out:
# (50, 2)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(BATCH_SIZE,
                            SEGMENTATION_TRAIN_DIR,
                            'image',
                            'dilate', 
                            train_generator_args,
                            target_size=(512,512),
                            save_to_dir=os.path.abspath(SEGMENTATION_AUG_DIR))

model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, \
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()

model_checkpoint = ModelCheckpoint('unet_lung_seg.hdf5', 
                                   monitor='loss', 
                                   verbose=1, 
                                   save_best_only=True)

history = model.fit_generator(train_gen,
                              steps_per_epoch=len(train_files) / BATCH_SIZE, 
                              epochs=EPOCHS, 
                              callbacks=[model_checkpoint],
                              validation_data = validation_data)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 1)  33          conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/56
# Found 842 images belonging to 1 classes.
# Found 842 images belonging to 1 classes.
# 421/421 [==============================] - 151s 358ms/step - loss: -0.4796 - dice_coef: 0.4796 - binary_accuracy: 0.3984 - val_loss: -0.6090 - val_dice_coef: 0.6090 - val_binary_accuracy: 0.6715
#
# Epoch 00001: loss improved from inf to -0.47965, saving model to unet_lung_seg.hdf5
# Epoch 2/56
# 421/421 [==============================] - 96s 227ms/step - loss: -0.6627 - dice_coef: 0.6627 - binary_accuracy: 0.6920 - val_loss: -0.7276 - val_dice_coef: 0.7276 - val_binary_accuracy: 0.8560
#
# Epoch 00002: loss improved from -0.47965 to -0.66266, saving model to unet_lung_seg.hdf5
# Epoch 3/56
# 421/421 [==============================] - 91s 215ms/step - loss: -0.6916 - dice_coef: 0.6916 - binary_accuracy: 0.7375 - val_loss: -0.7807 - val_dice_coef: 0.7807 - val_binary_accuracy: 0.8792
#
# Epoch 00003: loss improved from -0.66266 to -0.69161, saving model to unet_lung_seg.hdf5
# Epoch 4/56
# 421/421 [==============================] - 86s 205ms/step - loss: -0.7151 - dice_coef: 0.7151 - binary_accuracy: 0.7669 - val_loss: -0.7703 - val_dice_coef: 0.7703 - val_binary_accuracy: 0.8741
#
# Epoch 00004: loss improved from -0.69161 to -0.71510, saving model to unet_lung_seg.hdf5
# Epoch 5/56
# 421/421 [==============================] - 83s 197ms/step - loss: -0.7248 - dice_coef: 0.7248 - binary_accuracy: 0.7819 - val_loss: -0.8126 - val_dice_coef: 0.8126 - val_binary_accuracy: 0.9116
#
# Epoch 00005: loss improved from -0.71510 to -0.72481, saving model to unet_lung_seg.hdf5
# Epoch 6/56
# 421/421 [==============================] - 94s 224ms/step - loss: -0.7963 - dice_coef: 0.7963 - binary_accuracy: 0.8575 - val_loss: -0.8266 - val_dice_coef: 0.8266 - val_binary_accuracy: 0.9182
#
# Epoch 00006: loss improved from -0.72481 to -0.79625, saving model to unet_lung_seg.hdf5
# Epoch 7/56
# 421/421 [==============================] - 125s 296ms/step - loss: -0.8286 - dice_coef: 0.8286 - binary_accuracy: 0.8874 - val_loss: -0.8665 - val_dice_coef: 0.8665 - val_binary_accuracy: 0.9331
#
# Epoch 00007: loss improved from -0.79625 to -0.82863, saving model to unet_lung_seg.hdf5
# Epoch 8/56
# 421/421 [==============================] - 126s 300ms/step - loss: -0.8363 - dice_coef: 0.8363 - binary_accuracy: 0.8925 - val_loss: -0.8489 - val_dice_coef: 0.8489 - val_binary_accuracy: 0.9269
#
# Epoch 00008: loss improved from -0.82863 to -0.83625, saving model to unet_lung_seg.hdf5
# Epoch 9/56
# 421/421 [==============================] - 128s 305ms/step - loss: -0.8466 - dice_coef: 0.8466 - binary_accuracy: 0.8999 - val_loss: -0.8564 - val_dice_coef: 0.8564 - val_binary_accuracy: 0.9292
#
# Epoch 00009: loss improved from -0.83625 to -0.84655, saving model to unet_lung_seg.hdf5
# Epoch 10/56
# 421/421 [==============================] - 80s 190ms/step - loss: -0.8474 - dice_coef: 0.8474 - binary_accuracy: 0.9002 - val_loss: -0.8401 - val_dice_coef: 0.8401 - val_binary_accuracy: 0.9244
#
# Epoch 00010: loss improved from -0.84655 to -0.84737, saving model to unet_lung_seg.hdf5
# Epoch 11/56
# 421/421 [==============================] - 76s 181ms/step - loss: -0.8570 - dice_coef: 0.8570 - binary_accuracy: 0.9079 - val_loss: -0.8607 - val_dice_coef: 0.8607 - val_binary_accuracy: 0.9312
#
# Epoch 00011: loss improved from -0.84737 to -0.85696, saving model to unet_lung_seg.hdf5
# Epoch 12/56
# 421/421 [==============================] - 77s 183ms/step - loss: -0.8689 - dice_coef: 0.8689 - binary_accuracy: 0.9157 - val_loss: -0.8612 - val_dice_coef: 0.8612 - val_binary_accuracy: 0.9317
#
# Epoch 00012: loss improved from -0.85696 to -0.86892, saving model to unet_lung_seg.hdf5
# Epoch 13/56
# 421/421 [==============================] - 78s 185ms/step - loss: -0.8727 - dice_coef: 0.8727 - binary_accuracy: 0.9182 - val_loss: -0.8783 - val_dice_coef: 0.8783 - val_binary_accuracy: 0.9363
#
# Epoch 00013: loss improved from -0.86892 to -0.87273, saving model to unet_lung_seg.hdf5
# Epoch 14/56
# 421/421 [==============================] - 81s 193ms/step - loss: -0.8826 - dice_coef: 0.8826 - binary_accuracy: 0.9239 - val_loss: -0.8861 - val_dice_coef: 0.8861 - val_binary_accuracy: 0.9401
#
# Epoch 00014: loss improved from -0.87273 to -0.88259, saving model to unet_lung_seg.hdf5
# Epoch 15/56
# 421/421 [==============================] - 78s 186ms/step - loss: -0.8896 - dice_coef: 0.8896 - binary_accuracy: 0.9287 - val_loss: -0.8987 - val_dice_coef: 0.8987 - val_binary_accuracy: 0.9481
#
# Epoch 00015: loss improved from -0.88259 to -0.88958, saving model to unet_lung_seg.hdf5
# Epoch 16/56
# 421/421 [==============================] - 92s 219ms/step - loss: -0.8950 - dice_coef: 0.8950 - binary_accuracy: 0.9317 - val_loss: -0.8987 - val_dice_coef: 0.8987 - val_binary_accuracy: 0.9461
#
# Epoch 00016: loss improved from -0.88958 to -0.89501, saving model to unet_lung_seg.hdf5
# Epoch 17/56
# 421/421 [==============================] - 117s 277ms/step - loss: -0.8965 - dice_coef: 0.8965 - binary_accuracy: 0.9322 - val_loss: -0.9142 - val_dice_coef: 0.9142 - val_binary_accuracy: 0.9562
#
# Epoch 00017: loss improved from -0.89501 to -0.89646, saving model to unet_lung_seg.hdf5
# Epoch 18/56
# 421/421 [==============================] - 135s 320ms/step - loss: -0.9036 - dice_coef: 0.9036 - binary_accuracy: 0.9370 - val_loss: -0.9059 - val_dice_coef: 0.9059 - val_binary_accuracy: 0.9519
#
# Epoch 00018: loss improved from -0.89646 to -0.90357, saving model to unet_lung_seg.hdf5
# Epoch 19/56
# 421/421 [==============================] - 134s 318ms/step - loss: -0.9058 - dice_coef: 0.9058 - binary_accuracy: 0.9382 - val_loss: -0.8918 - val_dice_coef: 0.8918 - val_binary_accuracy: 0.9466
#
# Epoch 00019: loss improved from -0.90357 to -0.90577, saving model to unet_lung_seg.hdf5
# Epoch 20/56
# 421/421 [==============================] - 131s 311ms/step - loss: -0.9089 - dice_coef: 0.9089 - binary_accuracy: 0.9399 - val_loss: -0.9201 - val_dice_coef: 0.9201 - val_binary_accuracy: 0.9591
#
# Epoch 00020: loss improved from -0.90577 to -0.90888, saving model to unet_lung_seg.hdf5
# Epoch 21/56
# 421/421 [==============================] - 131s 310ms/step - loss: -0.9081 - dice_coef: 0.9081 - binary_accuracy: 0.9396 - val_loss: -0.9256 - val_dice_coef: 0.9256 - val_binary_accuracy: 0.9604
#
# Epoch 00021: loss did not improve from -0.90888
# Epoch 22/56
# 421/421 [==============================] - 129s 307ms/step - loss: -0.9131 - dice_coef: 0.9131 - binary_accuracy: 0.9426 - val_loss: -0.9367 - val_dice_coef: 0.9367 - val_binary_accuracy: 0.9667
#
# Epoch 00022: loss improved from -0.90888 to -0.91311, saving model to unet_lung_seg.hdf5
# Epoch 23/56
# 421/421 [==============================] - 127s 302ms/step - loss: -0.9128 - dice_coef: 0.9128 - binary_accuracy: 0.9423 - val_loss: -0.9296 - val_dice_coef: 0.9296 - val_binary_accuracy: 0.9634
#
# Epoch 00023: loss did not improve from -0.91311
# Epoch 24/56
# 421/421 [==============================] - 140s 332ms/step - loss: -0.9136 - dice_coef: 0.9136 - binary_accuracy: 0.9429 - val_loss: -0.9260 - val_dice_coef: 0.9260 - val_binary_accuracy: 0.9612
#
# Epoch 00024: loss improved from -0.91311 to -0.91360, saving model to unet_lung_seg.hdf5
# Epoch 25/56
# 421/421 [==============================] - 129s 306ms/step - loss: -0.9161 - dice_coef: 0.9161 - binary_accuracy: 0.9441 - val_loss: -0.9339 - val_dice_coef: 0.9339 - val_binary_accuracy: 0.9656
#
# Epoch 00025: loss improved from -0.91360 to -0.91607, saving model to unet_lung_seg.hdf5
# Epoch 26/56
# 421/421 [==============================] - 132s 312ms/step - loss: -0.9173 - dice_coef: 0.9173 - binary_accuracy: 0.9451 - val_loss: -0.9288 - val_dice_coef: 0.9288 - val_binary_accuracy: 0.9629
#
# Epoch 00026: loss improved from -0.91607 to -0.91733, saving model to unet_lung_seg.hdf5
# Epoch 27/56
# 421/421 [==============================] - 117s 279ms/step - loss: -0.9187 - dice_coef: 0.9187 - binary_accuracy: 0.9460 - val_loss: -0.9426 - val_dice_coef: 0.9426 - val_binary_accuracy: 0.9694
#
# Epoch 00027: loss improved from -0.91733 to -0.91865, saving model to unet_lung_seg.hdf5
# Epoch 28/56
# 421/421 [==============================] - 122s 290ms/step - loss: -0.9204 - dice_coef: 0.9204 - binary_accuracy: 0.9475 - val_loss: -0.9461 - val_dice_coef: 0.9461 - val_binary_accuracy: 0.9713
#
# Epoch 00028: loss improved from -0.91865 to -0.92044, saving model to unet_lung_seg.hdf5
# Epoch 29/56
# 421/421 [==============================] - 127s 302ms/step - loss: -0.9215 - dice_coef: 0.9215 - binary_accuracy: 0.9479 - val_loss: -0.9526 - val_dice_coef: 0.9526 - val_binary_accuracy: 0.9740
#
# Epoch 00029: loss improved from -0.92044 to -0.92154, saving model to unet_lung_seg.hdf5
# Epoch 30/56
# 421/421 [==============================] - 134s 318ms/step - loss: -0.9210 - dice_coef: 0.9210 - binary_accuracy: 0.9472 - val_loss: -0.9435 - val_dice_coef: 0.9435 - val_binary_accuracy: 0.9693
#
# Epoch 00030: loss did not improve from -0.92154
# Epoch 31/56
# 421/421 [==============================] - 134s 319ms/step - loss: -0.9218 - dice_coef: 0.9218 - binary_accuracy: 0.9480 - val_loss: -0.9352 - val_dice_coef: 0.9352 - val_binary_accuracy: 0.9662
#
# Epoch 00031: loss improved from -0.92154 to -0.92177, saving model to unet_lung_seg.hdf5
# Epoch 32/56
# 421/421 [==============================] - 126s 299ms/step - loss: -0.9234 - dice_coef: 0.9234 - binary_accuracy: 0.9489 - val_loss: -0.9567 - val_dice_coef: 0.9567 - val_binary_accuracy: 0.9769
#
# Epoch 00032: loss improved from -0.92177 to -0.92341, saving model to unet_lung_seg.hdf5
# Epoch 33/56
# 421/421 [==============================] - 122s 290ms/step - loss: -0.9235 - dice_coef: 0.9235 - binary_accuracy: 0.9493 - val_loss: -0.9513 - val_dice_coef: 0.9513 - val_binary_accuracy: 0.9740
#
# Epoch 00033: loss improved from -0.92341 to -0.92354, saving model to unet_lung_seg.hdf5
# Epoch 34/56
# 421/421 [==============================] - 124s 293ms/step - loss: -0.9249 - dice_coef: 0.9249 - binary_accuracy: 0.9498 - val_loss: -0.9565 - val_dice_coef: 0.9565 - val_binary_accuracy: 0.9765
#
# Epoch 00034: loss improved from -0.92354 to -0.92486, saving model to unet_lung_seg.hdf5
# Epoch 35/56
# 421/421 [==============================] - 129s 306ms/step - loss: -0.9252 - dice_coef: 0.9252 - binary_accuracy: 0.9500 - val_loss: -0.9574 - val_dice_coef: 0.9574 - val_binary_accuracy: 0.9771
#
# Epoch 00035: loss improved from -0.92486 to -0.92519, saving model to unet_lung_seg.hdf5
# Epoch 36/56
# 421/421 [==============================] - 117s 277ms/step - loss: -0.9243 - dice_coef: 0.9243 - binary_accuracy: 0.9497 - val_loss: -0.9597 - val_dice_coef: 0.9597 - val_binary_accuracy: 0.9779
#
# Epoch 00036: loss did not improve from -0.92519
# Epoch 37/56
# 421/421 [==============================] - 116s 274ms/step - loss: -0.9255 - dice_coef: 0.9255 - binary_accuracy: 0.9505 - val_loss: -0.9621 - val_dice_coef: 0.9621 - val_binary_accuracy: 0.9790
#
# Epoch 00037: loss improved from -0.92519 to -0.92548, saving model to unet_lung_seg.hdf5
# Epoch 38/56
# 421/421 [==============================] - 118s 280ms/step - loss: -0.9265 - dice_coef: 0.9265 - binary_accuracy: 0.9511 - val_loss: -0.9538 - val_dice_coef: 0.9538 - val_binary_accuracy: 0.9752
#
# Epoch 00038: loss improved from -0.92548 to -0.92653, saving model to unet_lung_seg.hdf5
# Epoch 39/56
# 421/421 [==============================] - 123s 291ms/step - loss: -0.9281 - dice_coef: 0.9281 - binary_accuracy: 0.9519 - val_loss: -0.9589 - val_dice_coef: 0.9589 - val_binary_accuracy: 0.9775
#
# Epoch 00039: loss improved from -0.92653 to -0.92808, saving model to unet_lung_seg.hdf5
# Epoch 40/56
# 421/421 [==============================] - 132s 314ms/step - loss: -0.9299 - dice_coef: 0.9299 - binary_accuracy: 0.9533 - val_loss: -0.9603 - val_dice_coef: 0.9603 - val_binary_accuracy: 0.9786
#
# Epoch 00040: loss improved from -0.92808 to -0.92987, saving model to unet_lung_seg.hdf5
# Epoch 41/56
# 421/421 [==============================] - 123s 292ms/step - loss: -0.9282 - dice_coef: 0.9282 - binary_accuracy: 0.9520 - val_loss: -0.9566 - val_dice_coef: 0.9566 - val_binary_accuracy: 0.9769
#
# Epoch 00041: loss did not improve from -0.92987
# Epoch 42/56
# 421/421 [==============================] - 105s 249ms/step - loss: -0.9285 - dice_coef: 0.9285 - binary_accuracy: 0.9524 - val_loss: -0.9587 - val_dice_coef: 0.9587 - val_binary_accuracy: 0.9769
#
# Epoch 00042: loss did not improve from -0.92987
# Epoch 43/56
# 421/421 [==============================] - 77s 183ms/step - loss: -0.9292 - dice_coef: 0.9292 - binary_accuracy: 0.9524 - val_loss: -0.9602 - val_dice_coef: 0.9602 - val_binary_accuracy: 0.9786
#
# Epoch 00043: loss did not improve from -0.92987
# Epoch 44/56
# 421/421 [==============================] - 77s 182ms/step - loss: -0.9303 - dice_coef: 0.9303 - binary_accuracy: 0.9537 - val_loss: -0.9701 - val_dice_coef: 0.9701 - val_binary_accuracy: 0.9835
#
# Epoch 00044: loss improved from -0.92987 to -0.93027, saving model to unet_lung_seg.hdf5
# Epoch 45/56
# 421/421 [==============================] - 75s 179ms/step - loss: -0.9324 - dice_coef: 0.9324 - binary_accuracy: 0.9545 - val_loss: -0.9684 - val_dice_coef: 0.9684 - val_binary_accuracy: 0.9827
#
# Epoch 00045: loss improved from -0.93027 to -0.93243, saving model to unet_lung_seg.hdf5
# Epoch 46/56
# 421/421 [==============================] - 75s 177ms/step - loss: -0.9318 - dice_coef: 0.9318 - binary_accuracy: 0.9545 - val_loss: -0.9645 - val_dice_coef: 0.9645 - val_binary_accuracy: 0.9808
#
# Epoch 00046: loss did not improve from -0.93243
# Epoch 47/56
# 421/421 [==============================] - 85s 201ms/step - loss: -0.9338 - dice_coef: 0.9338 - binary_accuracy: 0.9555 - val_loss: -0.9684 - val_dice_coef: 0.9684 - val_binary_accuracy: 0.9826
#
# Epoch 00047: loss improved from -0.93243 to -0.93378, saving model to unet_lung_seg.hdf5
# Epoch 48/56
# 421/421 [==============================] - 84s 199ms/step - loss: -0.9321 - dice_coef: 0.9321 - binary_accuracy: 0.9546 - val_loss: -0.9471 - val_dice_coef: 0.9471 - val_binary_accuracy: 0.9722
#
# Epoch 00048: loss did not improve from -0.93378
# Epoch 49/56
# 421/421 [==============================] - 72s 171ms/step - loss: -0.9331 - dice_coef: 0.9331 - binary_accuracy: 0.9554 - val_loss: -0.9672 - val_dice_coef: 0.9672 - val_binary_accuracy: 0.9817
#
# Epoch 00049: loss did not improve from -0.93378
# Epoch 50/56
# 421/421 [==============================] - 72s 171ms/step - loss: -0.9331 - dice_coef: 0.9331 - binary_accuracy: 0.9553 - val_loss: -0.9701 - val_dice_coef: 0.9701 - val_binary_accuracy: 0.9834
#
# Epoch 00050: loss did not improve from -0.93378
# Epoch 51/56
# 421/421 [==============================] - 75s 178ms/step - loss: -0.9347 - dice_coef: 0.9347 - binary_accuracy: 0.9563 - val_loss: -0.9708 - val_dice_coef: 0.9708 - val_binary_accuracy: 0.9840
#
# Epoch 00051: loss improved from -0.93378 to -0.93467, saving model to unet_lung_seg.hdf5
# Epoch 52/56
# 421/421 [==============================] - 76s 180ms/step - loss: -0.9358 - dice_coef: 0.9358 - binary_accuracy: 0.9572 - val_loss: -0.9705 - val_dice_coef: 0.9705 - val_binary_accuracy: 0.9837
#
# Epoch 00052: loss improved from -0.93467 to -0.93585, saving model to unet_lung_seg.hdf5
# Epoch 53/56
# 421/421 [==============================] - 76s 181ms/step - loss: -0.9349 - dice_coef: 0.9349 - binary_accuracy: 0.9569 - val_loss: -0.9654 - val_dice_coef: 0.9654 - val_binary_accuracy: 0.9810
#
# Epoch 00053: loss did not improve from -0.93585
# Epoch 54/56
# 421/421 [==============================] - 77s 183ms/step - loss: -0.9346 - dice_coef: 0.9346 - binary_accuracy: 0.9562 - val_loss: -0.9570 - val_dice_coef: 0.9570 - val_binary_accuracy: 0.9762
#
# Epoch 00054: loss did not improve from -0.93585
# Epoch 55/56
# 421/421 [==============================] - 73s 173ms/step - loss: -0.9366 - dice_coef: 0.9366 - binary_accuracy: 0.9576 - val_loss: -0.9651 - val_dice_coef: 0.9651 - val_binary_accuracy: 0.9811
#
# Epoch 00055: loss improved from -0.93585 to -0.93659, saving model to unet_lung_seg.hdf5
# Epoch 56/56
# 421/421 [==============================] - 73s 174ms/step - loss: -0.9364 - dice_coef: 0.9364 - binary_accuracy: 0.9575 - val_loss: -0.9719 - val_dice_coef: 0.9719 - val_binary_accuracy: 0.9845
#
# Epoch 00056: loss did not improve from -0.93659

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

training_accuracy = history.history['binary_accuracy']
validation_accuracy = history.history['val_binary_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %%
test_gen = test_generator(test_files, target_size=(512,512))
results = model.predict_generator(test_gen, len(test_files), verbose=1)
save_result(SEGMENTATION_TEST_DIR, results, test_files)
# Out:
# 50/50 [==============================] - 2s 35ms/step

# %%
image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0104_0.png")
predict_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0104_0_predict.png")
mask_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0104_0_dilate.png")

fig, axs = plt.subplots(4, 3, figsize=(16, 16))

axs[0, 0].set_title("Predicted")
axs[0, 0].imshow(add_colored_mask(image, predict_image))
axs[0, 1].set_title("Gold Std.")
axs[0, 1].imshow(add_colored_mask(image, mask_image))
axs[0, 2].set_title("Diff.")
axs[0, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/00000108_000.png")
predict_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/00000108_000_predict.png")
mask_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/00000108_000_dilate.png")

axs[1, 0].set_title("Predicted")
axs[1, 0].imshow(add_colored_mask(image, predict_image))
axs[1, 1].set_title("Gold Std.")
axs[1, 1].imshow(add_colored_mask(image, mask_image))
axs[1, 2].set_title("Diff.")
axs[1, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0290_0.png")
predict_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0290_0_predict.png")
mask_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/CHNCXR_0290_0_dilate.png")

axs[2, 0].set_title("Predicted")
axs[2, 0].imshow(add_colored_mask(image, predict_image))
axs[2, 1].set_title("Gold Std.")
axs[2, 1].imshow(add_colored_mask(image, mask_image))
axs[2, 2].set_title("Diff.")
axs[2, 2].imshow(diff_mask(mask_image, predict_image))

image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/MCUCXR_0040_0.png")
predict_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/MCUCXR_0040_0_predict.png")
mask_image = cv2.imread("/mnt/data/Smart-Detect/Segmentation/input_segmentation/segmentation/test/MCUCXR_0040_0_dilate.png")

axs[3, 0].set_title("Predicted")
axs[3, 0].imshow(add_colored_mask(image, predict_image))
axs[3, 1].set_title("Gold Std.")
axs[3, 1].imshow(add_colored_mask(image, mask_image))
axs[3, 2].set_title("Diff.")
axs[3, 2].imshow(diff_mask(mask_image, predict_image))
